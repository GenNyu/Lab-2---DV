# %% [markdown]
# <div style="text-align: center; background-color: #0A6EBD; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Lab 01 - TRỰC QUAN HOÁ DỮ LIỆU 📌
# </div>

# %% [markdown]
# <div style="text-align: center; background-color: #5A96E3; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Giai đoạn 00 - Khám phá dữ liệu 📌
# </div>

# %% [markdown]
# ### Nhập các thư viện cần thiết

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings

warnings.simplefilter('ignore')

# %% [markdown]
# ### Đọc dữ liệu

# %%
df = pd.read_csv("data/Aquifer_Petrignano.csv")
df
# Out:
#             Date  Rainfall_Bastia_Umbra  Depth_to_Groundwater_P24  \
# 0     14/03/2006                    NaN                    -22.48
# 1     15/03/2006                    NaN                    -22.38
# 2     16/03/2006                    NaN                    -22.25
# 3     17/03/2006                    NaN                    -22.38
# 4     18/03/2006                    NaN                    -22.60
# ...          ...                    ...                       ...
# 5218  26/06/2020                    0.0                    -25.68
# 5219  27/06/2020                    0.0                    -25.80
# 5220  28/06/2020                    0.0                    -25.80
# 5221  29/06/2020                    0.0                    -25.78
# 5222  30/06/2020                    0.0                    -25.91
#
#       Depth_to_Groundwater_P25  Temperature_Bastia_Umbra  \
# 0                       -22.18                       NaN
# 1                       -22.14                       NaN
# 2                       -22.04                       NaN
# 3                       -22.04                       NaN
# 4                       -22.04                       NaN
# ...                        ...                       ...
# 5218                    -25.07                      25.7
# 5219                    -25.11                      26.2
# 5220                    -25.19                      26.9
# 5221                    -25.18                      26.9
# 5222                    -25.25                      27.3
#
#       Temperature_Petrignano  Volume_C10_Petrignano  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN
# ...                      ...                    ...
# 5218                    24.5             -29930.688
# 5219                    25.0             -31332.960
# 5220                    25.7             -32120.928
# 5221                    26.0             -30602.880
# 5222                    26.5             -31878.144
#
#       Hydrometry_Fiume_Chiascio_Petrignano
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 5218                                   2.5
# 5219                                   2.4
# 5220                                   2.4
# 5221                                   2.4
# 5222                                   2.4
#
# [5223 rows x 8 columns]

# %% [markdown]
# ### Kích thước của tập dữ liệu

# %%
df.shape
# Out:
# (5223, 8)

# %% [markdown]
# ### Ý nghĩa của từng hàng
# - Mỗi dòng thể hiện thông tin các thuộc tính đo được trong 1 ngày tại Petrignano.

# %% [markdown]
# ### Kiểm tra hàng trùng lặp

# %%
duplicates = df.duplicated().sum()

print("There are {} duplicate rows in the dataset".format(duplicates))

df = df.drop_duplicates()

df.shape
# Out:
# There are 0 duplicate rows in the dataset
# (5223, 8)

# %% [markdown]
# ### Kiểm tra kiểu dữ liệu của các cột

# %%
data_types = df.dtypes
data_types
# Out:
# Date                                     object
# Rainfall_Bastia_Umbra                   float64
# Depth_to_Groundwater_P24                float64
# Depth_to_Groundwater_P25                float64
# Temperature_Bastia_Umbra                float64
# Temperature_Petrignano                  float64
# Volume_C10_Petrignano                   float64
# Hydrometry_Fiume_Chiascio_Petrignano    float64
# dtype: object

# %% [markdown]
# ### Xử lý dữ liệu
# Từ dữ liệu, có thể thấy dữ liệu bias và null đều trước 2009 nên nhóm sẽ lọc và chỉ lấy dữ liêu từ năm 2009.

# %%
df.isna().sum()
# Out:
# Date                                       0
# Rainfall_Bastia_Umbra                   1024
# Depth_to_Groundwater_P24                  55
# Depth_to_Groundwater_P25                  39
# Temperature_Bastia_Umbra                1024
# Temperature_Petrignano                  1024
# Volume_C10_Petrignano                    198
# Hydrometry_Fiume_Chiascio_Petrignano    1024
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Date                                    0
# Rainfall_Bastia_Umbra                   0
# Depth_to_Groundwater_P24                0
# Depth_to_Groundwater_P25                0
# Temperature_Bastia_Umbra                0
# Temperature_Petrignano                  0
# Volume_C10_Petrignano                   0
# Hydrometry_Fiume_Chiascio_Petrignano    0
# dtype: int64

# %%
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#          Date  Rainfall_Bastia_Umbra  Depth_to_Groundwater_P24  \
# 0  01/01/2009                    0.0                    -31.96
# 1  02/01/2009                    0.0                    -32.03
# 2  03/01/2009                    0.0                    -31.97
# 3  04/01/2009                    0.0                    -31.91
# 4  05/01/2009                    0.0                    -31.94
#
#    Depth_to_Groundwater_P25  Temperature_Bastia_Umbra  Temperature_Petrignano  \
# 0                    -31.14                       5.2                     4.9
# 1                    -31.11                       2.3                     2.5
# 2                    -31.07                       4.4                     3.9
# 3                    -31.05                       0.8                     0.8
# 4                    -31.01                      -1.9                    -2.1
#
#    Volume_C10_Petrignano  Hydrometry_Fiume_Chiascio_Petrignano
# 0             -24530.688                                   2.4
# 1             -28785.888                                   2.5
# 2             -25766.208                                   2.4
# 3             -27919.296                                   2.4
# 4             -29854.656                                   2.3

# %% [markdown]
# **Bỏ một số các cột mục tiêu để chúng ta chỉ có thể tập trung vào một mục tiêu trong mỗi thuộc tính.**

# %%
df = df.drop(['Depth_to_Groundwater_P24', 'Temperature_Petrignano'], axis=1)

# %%
df.head()
# Out:
#          Date  Rainfall_Bastia_Umbra  Depth_to_Groundwater_P25  \
# 0  01/01/2009                    0.0                    -31.14
# 1  02/01/2009                    0.0                    -31.11
# 2  03/01/2009                    0.0                    -31.07
# 3  04/01/2009                    0.0                    -31.05
# 4  05/01/2009                    0.0                    -31.01
#
#    Temperature_Bastia_Umbra  Volume_C10_Petrignano  \
# 0                       5.2             -24530.688
# 1                       2.3             -28785.888
# 2                       4.4             -25766.208
# 3                       0.8             -27919.296
# 4                      -1.9             -29854.656
#
#    Hydrometry_Fiume_Chiascio_Petrignano
# 0                                   2.4
# 1                                   2.5
# 2                                   2.4
# 3                                   2.4
# 4                                   2.3

# %% [markdown]
# **Đổi tên các cột theo hướng tổng quát**

# %%
df.columns = ['Date', 'Rainfall', 'Depth_to_Groundwater', 'Temperature', 'Drainage_Volume', 'River_Hydrometry']

targets = ['Depth_to_Groundwater']
features = [feature for feature in df.columns if feature not in targets]
df.head()
# Out:
#          Date  Rainfall  Depth_to_Groundwater  Temperature  Drainage_Volume  \
# 0  01/01/2009       0.0                -31.14          5.2       -24530.688
# 1  02/01/2009       0.0                -31.11          2.3       -28785.888
# 2  03/01/2009       0.0                -31.07          4.4       -25766.208
# 3  04/01/2009       0.0                -31.05          0.8       -27919.296
# 4  05/01/2009       0.0                -31.01         -1.9       -29854.656
#
#    River_Hydrometry
# 0               2.4
# 1               2.5
# 2               2.4
# 3               2.4
# 4               2.3

# %% [markdown]
# - ***Features:***
#     - **Rainfall**: Lượng mưa biểu thị lượng mưa rơi (mm)
#     - **Temperature**: Nhiệt độ biểu thị nhiệt độ (° C)
#     - **Drainage_Volume**: Thể tích cho biết thể tích nước lấy từ nhà máy xử lý nước uống (m3)
#     - **River_Hydrometry**: Tỷ trọng kế chỉ mực nước ngầm (m)
#
# - ***Target:***
#     - **Depth_to_Groundwater**: Độ sâu tới nước ngầm biểu thị mực nước ngầm (m tính từ tầng trệt)

# %% [markdown]
# ### Dữ liệu DateTime

# %% [markdown]
# Vì chúng ta đang làm việc với TimeSeries problem nên thuộc tính quan trọng nhất là thuộc tính thời gian, cụ thể là cột `Date`. Vì dữ liệu đã ở sẵn dạng `dd/mm/yyyy` nên không cần xử lý nhiều, chỉ cần chuyển đổi nó thành kiểu dữ liệu `datetime64`

# %%
from datetime import datetime, date 

df['Date'] = pd.to_datetime(df.Date, format = '%d/%m/%Y')
df.head().style.set_properties(subset=['Date'], **{'background-color': 'lightcoral'})
# Out:
# <style type="text/css">
# #T_a6a08_row0_col0, #T_a6a08_row1_col0, #T_a6a08_row2_col0, #T_a6a08_row3_col0, #T_a6a08_row4_col0 {
#   background-color: lightcoral;
# }
# </style>
# <table id="T_a6a08">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6a08_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_a6a08_level0_col1" class="col_heading level0 col1" >Rainfall</th>
#       <th id="T_a6a08_level0_col2" class="col_heading level0 col2" >Depth_to_Groundwater</th>
#       <th id="T_a6a08_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_a6a08_level0_col4" class="col_heading level0 col4" >Drainage_Volume</th>
#       <th id="T_a6a08_level0_col5" class="col_heading level0 col5" >River_Hydrometry</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6a08_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a6a08_row0_col0" class="data row0 col0" >2009-01-01 00:00:00</td>
#       <td id="T_a6a08_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_a6a08_row0_col2" class="data row0 col2" >-31.140000</td>
#       <td id="T_a6a08_row0_col3" class="data row0 col3" >5.200000</td>
#       <td id="T_a6a08_row0_col4" class="data row0 col4" >-24530.688000</td>
#       <td id="T_a6a08_row0_col5" class="data row0 col5" >2.400000</td>
#     </tr>
#     <tr>
#       <th id="T_a6a08_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a6a08_row1_col0" class="data row1 col0" >2009-01-02 00:00:00</td>
#       <td id="T_a6a08_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_a6a08_row1_col2" class="data row1 col2" >-31.110000</td>
#       <td id="T_a6a08_row1_col3" class="data row1 col3" >2.300000</td>
#       <td id="T_a6a08_row1_col4" class="data row1 col4" >-28785.888000</td>
#       <td id="T_a6a08_row1_col5" class="data row1 col5" >2.500000</td>
#     </tr>
#     <tr>
#       <th id="T_a6a08_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a6a08_row2_col0" class="data row2 col0" >2009-01-03 00:00:00</td>
#       <td id="T_a6a08_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_a6a08_row2_col2" class="data row2 col2" >-31.070000</td>
#       <td id="T_a6a08_row2_col3" class="data row2 col3" >4.400000</td>
#       <td id="T_a6a08_row2_col4" class="data row2 col4" >-25766.208000</td>
#       <td id="T_a6a08_row2_col5" class="data row2 col5" >2.400000</td>
#     </tr>
#     <tr>
#       <th id="T_a6a08_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a6a08_row3_col0" class="data row3 col0" >2009-01-04 00:00:00</td>
#       <td id="T_a6a08_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_a6a08_row3_col2" class="data row3 col2" >-31.050000</td>
#       <td id="T_a6a08_row3_col3" class="data row3 col3" >0.800000</td>
#       <td id="T_a6a08_row3_col4" class="data row3 col4" >-27919.296000</td>
#       <td id="T_a6a08_row3_col5" class="data row3 col5" >2.400000</td>
#     </tr>
#     <tr>
#       <th id="T_a6a08_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a6a08_row4_col0" class="data row4 col0" >2009-01-05 00:00:00</td>
#       <td id="T_a6a08_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_a6a08_row4_col2" class="data row4 col2" >-31.010000</td>
#       <td id="T_a6a08_row4_col3" class="data row4 col3" >-1.900000</td>
#       <td id="T_a6a08_row4_col4" class="data row4 col4" >-29854.656000</td>
#       <td id="T_a6a08_row4_col5" class="data row4 col5" >2.300000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Các giá trị được phân bổ với mỗi cột số

# %%
# Setting the plot style
sns.set(style="whitegrid")
# lọc ra các cột numerical
numerical_columns = df.select_dtypes(include=['float64', 'int64'])
# Plotting distributions
for column in numerical_columns:
    plt.figure(figsize=(10, 4))
    sns.histplot(df[column], bins=30, kde=True)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# ### Time-Series Features

# %%
fig, axs = plt.subplots(nrows=5, ncols=1, figsize=(15, 25))

# Lặp qua các cột trong DataFrame trừ cột 'Date'
for i, column in enumerate(df.drop('Date', axis=1).columns):
    # Vẽ đồ thị dạng đường
    sns.lineplot(x=df['Date'], y=df[column].fillna(method='ffill'), ax=axs[i], color='dodgerblue', linewidth=1.5)
    
    # Thiết lập tiêu đề và nhãn trục y
    axs[i].set_title('Feature: {}'.format(column), fontsize=14)
    axs[i].set_ylabel(ylabel=column, fontsize=14)
    
    # Thiết lập giới hạn trục x
    axs[i].set_xlim([date(2009, 1, 1), date(2020, 6, 30)])   

    # Tăng kích thước của các nhãn trục và tiêu đề
    axs[i].tick_params(axis='x', labelsize=10)
    axs[i].tick_params(axis='y', labelsize=10)
    axs[i].title.set_size(16)

# Hiển thị đồ thị
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Thống kê mô tả

# %%
df.describe()
# Out:
#                                 Date     Rainfall  Depth_to_Groundwater  \
# count                           4150  4150.000000           4150.000000
# mean   2014-09-30 09:45:42.939759104     1.554723            -25.177504
# min              2009-01-01 00:00:00     0.000000            -33.710000
# 25%              2011-11-04 06:00:00     0.000000            -26.877500
# 50%              2014-10-13 12:00:00     0.000000            -25.145000
# 75%              2017-08-15 18:00:00     0.000000            -23.262500
# max              2020-06-30 00:00:00    67.300000            -19.100000
# std                              NaN     5.232954              2.951859
#
#        Temperature  Drainage_Volume  River_Hydrometry
# count  4150.000000      4150.000000       4150.000000
# mean     15.046747    -28647.225785          2.370265
# min      -3.700000    -41890.176000          0.000000
# 25%       8.800000    -31065.768000          2.100000
# 50%      14.700000    -28375.056000          2.400000
# 75%      21.400000    -26028.864000          2.700000
# max      33.000000         0.000000          4.100000
# std       7.803718      4573.361338          0.591042

# %% [markdown]
# ### Lưu dữ liệu vào tệp .csv

# %%
save_name = "Water_Cleaner.csv"
df.to_csv("./data/" + save_name, index=False)
